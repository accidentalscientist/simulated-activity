# %% [markdown]
# # Seasonality Decomposition\nGenerated archive notebook section for 2020-03-01.\n

# %%
import math\nseries = [math.sin(i / 6) + i * 0.01 for i in range(120)]\nrolling = [sum(series[i:i+12]) / 12 for i in range(len(series) - 11)]\nrolling[:5]\n
